# %% [markdown]
# # Data Collection - 数据采集主入口
#
# **功能**: 统一执行所有数据采集步骤
#
# **步骤**:
# 1. 获取股票列表
# 2. 采集日线数据
# 3. 采集财务指标
# 4. 采集事件数据

# %% [markdown]
# ## 执行顺序
#
# ### 已实现：
# 1. [01_fetch_stock_list.ipynb](./01_fetch_stock_list.ipynb) - 获取股票列表
# 2. [02_fetch_daily_data.ipynb](./02_fetch_daily_data.ipynb) - 采集日线数据
#
# ### 待实现：
# 3. 03_fetch_fundamentals.ipynb - 采集财务指标
# 4. 04_fetch_events.ipynb - 采集事件数据（减持/解禁）

# %% [markdown]
# ## 快速执行
#
# ```bash
# jupyter nbconvert --to notebook --execute 01_fetch_stock_list.ipynb
# jupyter nbconvert --to notebook --execute 02_fetch_daily_data.ipynb
# ```

# %% [markdown]
# ## 下一步
#
# 数据采集完成后，继续执行：
# - [../02_technical_factors/main.ipynb](../02_technical_factors/main.ipynb) - 技术因子计算
